# %% [markdown]
# # Musical note analysis
# M C M Wright, ISVR, University of Southampton

# %% [markdown]
# In this notebook we will important samples of notes played on orchestral instruments, and analyse them to see how their characteristics vary with pitch and volume.
#
# The samples can be downloaded from the Philharmonia website.

# %%
# %pylab inline
import os
from scipy.io import wavfile
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fname = '..\\instruments\\flute\\flute_A4_05_forte_normal'
os.system('ffmpeg -i {}.mp3 temp.wav'.format(fname))
Fs, x = wavfile.read('temp.wav')
os.system('del temp.wav')
# Out:
# 0

# %%
plot(x)

# %%
f = 440
T = 1.0/f
dt = 1.0/Fs
plot(x[10000:(10000 + 3*T/dt)])

# %%
t_start = random.uniform(low = 0.1, high = 0.6, size = 5)
ind3 = arange(0, 3*T*Fs, dtype = int)
ind1 = arange(0, T*Fs, dtype = int)

for (n, t_s) in enumerate(t_start):
    rel_ind = int(t_s*Fs)
    samp = x[rel_ind + ind1]
    p = argmax(samp)
    plot(t[ind1], x[rel_ind + p + ind1] + 2000*n)
    axis('off')

# %%
rint(3.4)
# Out:
# 3.0
